# %% [markdown]
# # AirBnB Rome Listings Analysis

# %% [markdown]
# ## Data Set Exploration

# %% [markdown]
# #### -Reading AirBnb Rome listings data
# #### -Casting data columns as a datetime format
# #### -Checking missing values, calculating minimum, maximum, and avergae for each numeric field

# %%
import pandas as pd

listings = pd.read_csv("listings.csv")

listings
# Out:
#                  id                         name rating   bedrooms    beds  \
# 0      3.563629e+07       Boutique hotel in Rome  ★4.81  1 bedroom   1 bed
# 1      2.399029e+06          Rental unit in Rome  ★4.67  1 bedroom  2 beds
# 2      2.709785e+06          Rental unit in Rome  ★4.71  1 bedroom  2 beds
# 3      7.476560e+05          Rental unit in Rome  ★4.86  1 bedroom   1 bed
# 4      1.262834e+06                 Loft in Rome  ★4.80  1 bedroom   1 bed
# ...             ...                          ...    ...        ...     ...
# 29352  8.585630e+17  Rental unit in Marco Simone    NaN     Studio  4 beds
# 29353  2.144243e+07                 Home in Rome    NaN     Studio  6 beds
# 29354  4.374142e+07          Rental unit in Rome    NaN     Studio     NaN
# 29355  4.162720e+07                 Loft in Rome    NaN     Studio     NaN
# 29356  3.000372e+07            Tiny home in Rome    NaN        NaN   1 bed
#
#                 baths    host_id host_name  host_since host_is_superhost  ...  \
# 0           1.5 baths   20028020  Viminale   8/14/2014                 t  ...
# 1      1 private bath   12258559    Marisa   2/15/2014                 f  ...
# 2             2 baths   12258559    Marisa   2/15/2014                 f  ...
# 3              1 bath    3925580      Rita  10/20/2012                 t  ...
# 4              1 bath    6876317   Germana   6/12/2013                 t  ...
# ...               ...        ...       ...         ...               ...  ...
# 29352          1 bath  476618395   Roberta   8/25/2022                 f  ...
# 29353         2 baths   27960003    Pietro   2/18/2015                 f  ...
# 29354  0 shared baths  309042401   Melania  11/12/2019                 f  ...
# 29355          1 bath  155760249  Giovanni  10/22/2017                 f  ...
# 29356   1 shared bath  225538709    Dalido  11/13/2018                 f  ...
#
#        longitude                property_type        room_type accommodates  \
# 0      12.495944       Room in boutique hotel     Private room            2
# 1      12.490240  Private room in rental unit     Private room            2
# 2      12.490250  Private room in rental unit     Private room            2
# 3      12.471450           Entire rental unit  Entire home/apt            2
# 4      12.472890                  Entire loft  Entire home/apt            2
# ...          ...                          ...              ...          ...
# 29352  12.633060           Entire rental unit  Entire home/apt            4
# 29353  12.499730                  Entire home  Entire home/apt            7
# 29354  12.527350  Private room in rental unit     Private room            2
# 29355  12.480130                  Entire loft  Entire home/apt           16
# 29356  12.601390    Private room in tiny home     Private room            1
#
#        price  number_of_reviews number_of_reviews_ltm number_of_reviews_l30d  \
# 0       91.0           1,879.00                   601                     54
# 1       80.0           1,081.00                   117                      4
# 2       80.0           1,027.00                   130                      6
# 3       91.0                908                   106                      6
# 4      120.0                880                   104                      5
# ...      ...                ...                   ...                    ...
# 29352    NaN                  0                     0                      0
# 29353  263.0                  0                     0                      0
# 29354    NaN                  0                     0                      0
# 29355    NaN                  0                     0                      0
# 29356   40.0                  0                     0                      0
#
#        first_review  last_review
# 0        12/16/2019   12/15/2023
# 1          4/6/2014   12/10/2023
# 2         4/15/2014   12/12/2023
# 3        10/29/2012   12/12/2023
# 4          8/6/2013   11/30/2023
# ...             ...          ...
# 29352           NaN          NaN
# 29353           NaN          NaN
# 29354           NaN          NaN
# 29355           NaN          NaN
# 29356           NaN          NaN
#
# [29357 rows x 25 columns]

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         29357 non-null  float64
#  1   name                       29357 non-null  object
#  2   rating                     23893 non-null  object
#  3   bedrooms                   29339 non-null  object
#  4   beds                       29004 non-null  object
#  5   baths                      29319 non-null  object
#  6   host_id                    29357 non-null  int64
#  7   host_name                  29348 non-null  object
#  8   host_since                 29348 non-null  object
#  9   host_is_superhost          29163 non-null  object
#  10  host_listings_count        29348 non-null  object
#  11  host_total_listings_count  29348 non-null  object
#  12  host_identity_verified     29348 non-null  object
#  13  neighbourhood_cleansed     29357 non-null  object
#  14  latitude                   29357 non-null  float64
#  15  longitude                  29357 non-null  float64
#  16  property_type              29357 non-null  object
#  17  room_type                  29357 non-null  object
#  18  accommodates               29357 non-null  int64
#  19  price                      27381 non-null  float64
#  20  number_of_reviews          29357 non-null  object
#  21  number_of_reviews_ltm      29357 non-null  int64
#  22  number_of_reviews_l30d     29357 non-null  int64
#  23  first_review               25086 non-null  object
#  24  last_review                25086 non-null  object
# dtypes: float64(4), int64(4), object(17)
# memory usage: 5.6+ MB

# %%
listings["host_since"] = pd.to_datetime(listings["host_since"])

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         29357 non-null  float64
#  1   name                       29357 non-null  object
#  2   rating                     23893 non-null  object
#  3   bedrooms                   29339 non-null  object
#  4   beds                       29004 non-null  object
#  5   baths                      29319 non-null  object
#  6   host_id                    29357 non-null  int64
#  7   host_name                  29348 non-null  object
#  8   host_since                 29348 non-null  datetime64[ns]
#  9   host_is_superhost          29163 non-null  object
#  10  host_listings_count        29348 non-null  object
#  11  host_total_listings_count  29348 non-null  object
#  12  host_identity_verified     29348 non-null  object
#  13  neighbourhood_cleansed     29357 non-null  object
#  14  latitude                   29357 non-null  float64
#  15  longitude                  29357 non-null  float64
#  16  property_type              29357 non-null  object
#  17  room_type                  29357 non-null  object
#  18  accommodates               29357 non-null  int64
#  19  price                      27381 non-null  float64
#  20  number_of_reviews          29357 non-null  object
#  21  number_of_reviews_ltm      29357 non-null  int64
#  22  number_of_reviews_l30d     29357 non-null  int64
#  23  first_review               25086 non-null  object
#  24  last_review                25086 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(4), object(16)
# memory usage: 5.6+ MB

# %%
rome_listings = listings.loc[:, ["host_since", "neighbourhood_cleansed", "accommodates", "price"]]

# %%
rome_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29357 entries, 0 to 29356
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   host_since              29348 non-null  datetime64[ns]
#  1   neighbourhood_cleansed  29357 non-null  object
#  2   accommodates            29357 non-null  int64
#  3   price                   27381 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 917.5+ KB

# %%
rome_listings.isna().sum()
# Out:
# host_since                   9
# neighbourhood_cleansed       0
# accommodates                 0
# price                     1976
# dtype: int64

# %%
rome_listings.describe()
# Out:
#                           host_since  accommodates         price
# count                          29348  29357.000000  27381.000000
# mean   2017-04-10 02:15:07.727953920      3.704738    172.378912
# min              2008-08-13 00:00:00      1.000000      8.000000
# 25%              2014-08-27 00:00:00      2.000000     76.000000
# 50%              2016-08-01 00:00:00      4.000000    105.000000
# 75%              2019-09-24 00:00:00      4.000000    157.000000
# max              2023-12-13 00:00:00     16.000000  80000.000000
# std                              NaN      2.047440    712.298687

# %%
rome_listings.query("price == 0").count()
# Out:
# host_since                0
# neighbourhood_cleansed    0
# accommodates              0
# price                     0
# dtype: int64

# %% [markdown]
# ## Prepare for Visualization

# %% [markdown]
# #### -Creating a DataFrame rome_listings_neighborhood. Grouping the Rome listings by neighborhood and calculating the average price for each. Sorting by price in ascending order.
# #### -Creating a DataFrame rome_listings_accommodates. Filtering down to the most expensive neighborhoods in Rome. Grouping it by accommodates and calculating the average price fro each. Sort by price in ascending order.
# #### -Creating a DataFrame rome_listings_over_time. Grouping the data by the year component of host_since. Calculating a count of rows to get the number of new hosts for each year, and the average price of listings for each year.

# %%
rome_listings_neighborhood = ( 
    rome_listings
    .groupby("neighbourhood_cleansed")
    .agg({"price":"mean"})
    .sort_values("price")
)

rome_listings_neighborhood.tail()
# Out:
#                              price
# neighbourhood_cleansed
# IV Tiburtina            164.477778
# II Parioli/Nomentano    171.396699
# IX Eur                  181.645833
# I Centro Storico        191.266581
# X Ostia/Acilia          207.660881

# %%
rome_listings_accommodates = (
    rome_listings
    .query("neighbourhood_cleansed == 'I Centro Storico'")
    .groupby("accommodates")
    .agg({"price":"mean"})
    .sort_values("price")
)
rome_listings_accommodates.head()
# Out:
#                    price
# accommodates
# 1             118.531915
# 2             143.858994
# 3             149.828231
# 4             179.455090
# 5             194.409865

# %%
rome_listings_over_time = (
    rome_listings
    .set_index("host_since")
    .resample("Y")
    .agg({
        "neighbourhood_cleansed" : "count",
        "price" : "mean"
    })
)

rome_listings_over_time.head()
# Out:
#             neighbourhood_cleansed       price
# host_since
# 2008-12-31                      18   75.058824
# 2009-12-31                       8  115.857143
# 2010-12-31                     282  152.456522
# 2011-12-31                     901  167.342497
# 2012-12-31                    1714  158.922500

# %% [markdown]
# ## Visualize the data

# %% [markdown]
# #### -Building a horizontal bar chart of average rent price by the neighborhood.
# #### -Building a horizontal bar chart of average price by accommodates in the most expensive neighborhood.
# #### -Building line charts of new hosts per year and average price by year.
# #### -Plotting both time series in dual axis line chart.

# %%
import seaborn as sns

(rome_listings_neighborhood
 .plot
 .barh(
     title="Average Listing Price by Rome Neighborhood", 
     xlabel="Price Per Night (USD)", 
     ylabel="Neighborhood",
     legend=None
 )
)

sns.despine()

# %%
(rome_listings_accommodates
 .plot
 .barh(
     title="Average Listing Price by Accommodation Number", 
     xlabel="Price Per Night (USD)", 
     ylabel="Accommodation Capacity",
     legend=None
 )
)

sns.despine()

# %%
rome_listings_over_time["neighbourhood_cleansed"].plot(
    ylabel="New Hosts",
    title="New AirBnB Hosts in Rome Over Time"
)

sns.despine()

# %%
rome_listings_over_time["price"].plot(
    ylabel="Average Price (USD)",
    title="Average AirBnB Price in Rome Over Time"
)

sns.despine()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(
    rome_listings_over_time.index,
    rome_listings_over_time["neighbourhood_cleansed"],
    label="New Hosts",
    c="purple"
)

ax.set_ylabel("New Hosts")

ax2 = ax.twinx()

ax2.plot(
    rome_listings_over_time.index,
    rome_listings_over_time["price"],
    label="Average Price",
)
ax2.set_ylim(0)

ax2.set_ylabel("Average Price")

ax.set_title("Increase of  New Hosts Number and Average Accommodation Price after COVID")

ax.legend()
ax2.legend()
